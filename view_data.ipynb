# %%
import pandas as pd

df = pd.read_csv('data.csv')
df
# Out:
#      True  12.332  6.796148949754909  0.0  10.0    0  2.9737327098846436  \
# 0    True  12.332           6.796149  0.0  10.0  0.0            2.972657
# 1    True  12.332           6.796149  0.0  10.0  0.0            2.971648
# 2    True  12.332           6.796149  0.0  10.0  0.0            2.973488
# 3    True  12.332           6.796149  0.0  10.0  0.0            2.971055
# 4    True  12.332           6.796149  0.0  10.0  0.0            2.970371
# 5    True  12.332           6.796149  0.0  10.0  0.0            2.970584
# 6    True  12.332           6.796149  0.0  10.0  0.0            2.969502
# 7    True  12.332           6.796149  0.0  10.0  0.0            2.969686
# 8    True  12.332           6.796149  0.0  10.0  0.0            2.968663
# 9    True  12.332           6.796149  0.0  10.0  0.0            2.969357
# 10   True  12.332           6.796149  0.0  10.0  0.0            2.968341
# 11   True  12.332           6.796149  0.0  10.0  0.0            2.968094
# ...

# %%
df.describe()
# Out:
#         success  actual_time  optimal_time  lidar_0  lidar_1  lidar_2  \
# count         0            0             0        0        0        0
# unique        0            0             0        0        0        0
#
#         lidar_3  lidar_4  lidar_5  lidar_6  ...  lidar_717  lidar_718  \
# count         0        0        0        0  ...          0          0
# unique        0        0        0        0  ...          0          0
#
#         lidar_719  pos_x  pos_y  pose_heading  twist_linear  twist_angular  \
# count           0      0      0             0             0              0
# unique          0      0      0             0             0              0
#
#         cmd_vel_linear  cmd_vel_angular
# count                0                0
# unique               0                0
#
# [2 rows x 730 columns]
